# %%
import numpy as np

# %%
matrix = np.array([[1, 2, 3], [4, 5, 6]])
matrix.shape  # dimension
matrix.dtype  # data type
matrix.device  # cpu
print(matrix.flags)
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False

# %%
matrix.flatten("A")
matrix.flatten("C")
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# 💡 This is literally linear regression

# %%
X = np.array([[1500, 3], [1800, 4], [1200, 2]])  # house size, rooms
weights = np.array([0.5, 1.2])
prediction = X @ weights  # Multiply matrix X with vector weights
print(prediction)
# Out:
# [753.6 904.8 602.4]

# %%
np.std(X)
# Out:
# np.float64(768.2789749390083)

# %%
np.mean(X)
# Out:
# np.float64(751.5)

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
print(a + b)  # vector addition✅[1+4, 2+5, 3+6]
print(a * b)  # element-wise multiplication ✅[1*4, 2*5, 3*6]
print(a @ b) #@ = dot / matrix multiplication ✅ 1*4 + 2*5 + 3*6 = 32
# Out:
# [5 7 9]
# [ 4 10 18]
# 32
